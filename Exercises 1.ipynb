# %%
import math

# %% [markdown]
# # Exercises

# %% [markdown]
# #### 1. Create the following variables, checking that value and type are correct (using print and type):

# %% [markdown]
# a. a and b with values 12 and 23 as integers.

# %%
a = 12
print(f'the value of a is {a} and the type is {type(a)}')
b = 23
print(f'the value of b is {b} and the type is {type(b)}')
# Out:
# the value of a is 12 and the type is <class 'int'>
# the value of b is 23 and the type is <class 'int'>
# the value of x is 21 and the type is <class 'int'>
# the value of y is 14 and the type is <class 'int'>

# %% [markdown]
# b. x and y with values 21 and 14 as floats.

# %%
x = 21
print(f'the value of x is {x} and the type is {type(x)}')
y = 14
print(f'the value of y is {y} and the type is {type(y)}')

# %% [markdown]
# #### 2. Using print (once), print:

# %% [markdown]
# a. All the above variables in the same line.

# %%
print(a, b, x, y)
# Out:
# 12 23 21 14

# %% [markdown]
# b. x and y with values 21 and 14 as floats.

# %%
print(a, ";", b, ";", x, ";", y, ";",)
# Out:
# 12 ; 23 ; 21 ; 14 ;

# %% [markdown]
# c. The text “the product of a and b is a * b”, replacing a, b and a * b with the variable values.

# %%
print(f'the product of {a} and {b} is {a*b}')
# Out:
# the product of 12 and 23 is 276

# %% [markdown]
# #### 3. Find the value and the type of:

# %% [markdown]
# a. The product of a and b.

# %%
print(f'the value of a*b is {a*b} and the type is {type(a*b)}')
# Out:
# the value of a*b is 276 and the type is <class 'int'>

# %% [markdown]
# b. The division of x by y.

# %%
print(f'the value of x/y is {x/y} and the type is {type(x/y)}')
# Out:
# the value of x/y is 1.5 and the type is <class 'float'>

# %% [markdown]
# c. The integer division of a by b.

# %%
print(f'the value of a//b is {a//b} and the type is {type(a//b)}')
# Out:
# the value of a//b is 0 and the type is <class 'int'>

# %% [markdown]
# d. The integer division of x by y.

# %%
print(f'the value of x//y is {x//y} and the type is {type(x//y)}')
# Out:
# the value of x//y is 1 and the type is <class 'int'>

# %% [markdown]
# e. The product of b and y.

# %%
print(f'the value of b*y is {b*y} and the type is {type(b*y)}')
# Out:
# the value of b*y is 322 and the type is <class 'int'>

# %% [markdown]
# f. 2 to the power 0.

# %%
print(f'the value of 2^0 is {2**0} and the type is {type(2**0)}')
# Out:
# the value of 2^0 is 1 and the type is <class 'int'>

# %% [markdown]
# g. 2 to the power 100.

# %%
print(f'the value of 2^100 is {2**100} and the type is {type(2**100)}')
# Out:
# the value of 2^100 is 1267650600228229401496703205376 and the type is <class 'int'>

# %% [markdown]
# h. 2 to the power 1.2.

# %%
print(f'the value of 2^1.2 is {2**1.2} and the type is {type(2**1.2)}')
# Out:
# the value of 2^1.2 is 2.2973967099940698 and the type is <class 'float'>

# %% [markdown]
# i. 2 to the power -2.

# %%
print(f'the value of 2^-2 is {2**-2} and the type is {type(2**-2)}')
# Out:
# the value of 2^-2 is 0.25 and the type is <class 'float'>

# %% [markdown]
# j. The square root of 4.

# %%
print(f'the value of square root of 4 is {math.sqrt(4)} and the type is {type(math.sqrt(4))}')
# Out:
# the value of square root of 4 is 2.0 and the type is <class 'float'>

# %% [markdown]
# k. The square root of 2.

# %%
print(f'the value of square root of 2 is {math.sqrt(2)} and the type is {type(math.sqrt(2))}')
# Out:
# the value of square root of 2 is 1.4142135623730951 and the type is <class 'float'>

# %% [markdown]
# #### 4. What is the difference between:

# %% [markdown]
# a. 10 / 12
#
# "/" is the operator true division
# ```
# ```

# %% [markdown]
# #### 5. Using pi = 3.141592 and given r = 2.5, calculate:

# %%
pi = 3.141592
r = 2.5

# %% [markdown]
# a. The circumference of a circle with radius r: $2*pi*r$.

# %%
print(2*pi*r)
# Out:
# 15.70796

# %% [markdown]
# b. The area of a circle with radius r: $\pi*r^2$.

# %%
print(pi*r**2)
# Out:
# 19.63495

# %% [markdown]
# c. The volume of a sphere with radius r:$\frac{4}{3}*\pi*r^3$.

# %%
print(4/3*pi*r**3)
# Out:
# 65.44983333333333

# %% [markdown]
# #### 6. Create 2 variables a = 100 and b = True. Using an adequate number of extra variables (with arbitrary names!), give the value of a to b and vice versa. (Writing a = True and b = 100 is not sufficient!) Can it be done with only one extra variable?

# %%
a = 100
b = True
print(a, b)
print("-"*20)
extra_variable = a
a = b
b = extra_variable
print(a,b)
print("-"*20)
# Out:
# 100 True
# --------------------
# True 100
# --------------------

# %% [markdown]
# #### 7.On the same strand of DNA there are 2 genes. The first includes nucleotides from position 10 to position 20, the second nucleotides from position 30 to position 40. Let us write this:

# %%
gene1_start, gene1_end = 10, 20
gene2_start, gene2_end = 30, 40

# %% [markdown]
# Given a variable pos representing an arbitrary position on the DNA strand, write some comparisons to verify if:

# %% [markdown]
# a. pos is in the first gene.

# %%
pos = 12
if pos>=gene1_start and pos<=gene1_end:
  print("pos is in the first gene")
else:
    print("pos isn't in the first gene")
# Out:
# pos is in the first gene

# %% [markdown]
# b. pos is in the second gene.

# %%
pos = 30
if pos>=gene2_start and pos<=gene2_end:
  print("pos is in the first gene")
else:
    print("pos isn't in the first gene")
# Out:
# pos isn't in the first gene

# %% [markdown]
# c. pos is between the start of the first gene and the end of the second.

# %%
pos = 12
if pos>=gene1_start and pos<=gene2_end:
  print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# d. pos is between the start of the first gene and the end of the second, but not in any of the
# genes.

# %%
pos = 21
if pos>=gene1_start and pos<=gene2_end:
  if pos>gene1_end and pos<gene2_start:
    print(False)
  else:
    print(True)
else:
    print(False)
# Out:
# False

# %% [markdown]
# e. pos is before the start of the first gene or after the end of the second.

# %%
pos = 55
if pos<=gene1_start or pos>=gene2_end:
  print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# f. pos is inside one of the genes.

# %%
pos = 55
if pos>=gene1_start and pos<=gene1_end or pos>=gene2_start and pos<=gene2_end:
  print(True)
else:
    print(False)
# Out:
# False

# %% [markdown]
# g. pos is distant no more than 10 nucleotides from the beginning of the first gene.

# %%
pos = 20
if pos>=gene1_start-10 and pos<=gene1_start+10:
  print(True)
else:
    print(False)
# Out:
# True
